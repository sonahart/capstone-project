# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Identify the distribution of data in the dataset.
#
# *   Identify outliers in the dataset.
#
# *   Remove outliers from the dataset.
#
# *   Identify correlation between features in the dataset.

# %% [markdown]
# ***

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %%
df.head()
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...

# %%
df['ConvertedComp']
# Out:
# 0         61000.0
# 1         95179.0
# 2         90000.0
# 3        455352.0
# 4         65277.0
#            ...
# 11393    130000.0
# 11394     19880.0
# 11395    105000.0
# 11396     80371.0
# 11397         NaN
# Name: ConvertedComp, Length: 11398, dtype: float64

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
# your code goes here
sns.kdeplot(df['ConvertedComp'])
plt.show()

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
# your code goes here
sns.histplot(df['ConvertedComp'],bins=10)
plt.show()

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
# your code goes here
df['ConvertedComp'].median()
# Out:
# 57745.0

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
# your code goes here
man_num = df['Gender'].value_counts()[0]
print(f'The number of responders that identify as men is: {man_num}')
# Out:
# The number of responders that identify as men is: 10480

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
# your code goes here
wom_median = df['ConvertedComp'][df['Gender'] == 'Woman'].median()
print(f'The median converted compensation of responders that identify as women is: {wom_median}')
# Out:
# The median converted compensation of responders that identify as women is: 57708.0

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
# your code goes here
age_min = int(df['Age'].min())
age_q1 = df['Age'].quantile(0.25)
age_median = df['Age'].median()
age_q3 = df['Age'].quantile(0.75)
age_max  = df['Age'].max()

print(f'The five number summary for Age are: \nMin: {int(age_min)}\nQ1: {int(age_q1)}\nMedian: {int(age_median)}\nQ3: {int(age_q3)}\nMax: {int(age_max)}')
# Out:
# The five number summary for Age are:
# Min: 16
# Q1: 25
# Median: 29
# Q3: 35
# Max: 99

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
# your code goes here
sns.histplot(df['Age'],bins=20)
plt.show()

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
df['ConvertedComp'].min()
# Out:
# 0.0

# %%
sns.boxplot(df['Age'])
plt.show()
# Out:
# c:\Users\kevez\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# your code goes here
sns.boxplot(df['ConvertedComp'])
plt.show()
# Out:
# c:\Users\kevez\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
# your code goes here
q1 = df['ConvertedComp'].quantile(0.25)
q3 = df['ConvertedComp'].quantile(0.75)

iqr = q3 - q1

print(f'The Inter Quartile Range of ConvertedComp is: {int(iqr)}')
# Out:
# The Inter Quartile Range of ConvertedComp is: 73132

# %% [markdown]
# Find out the upper and lower bounds.

# %%
# your code goes here
comp_min = q1 -( 1.5 * iqr) 
comp_max = q3 + (1.5 * iqr) 

print(f'The lower bound is {int(comp_min)} and the upper bound is {int(comp_max)}')
# Out:
# The lower bound is -82830 and the upper bound is 209698

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
# your code goes here
def find_outliers_IQR(df):

   q1=df.quantile(0.25)

   q3=df.quantile(0.75)

   IQR=q3-q1

   outliers = df[((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]

   return outliers

outliers = find_outliers_IQR(df['ConvertedComp'])

print('number of outliers:'+ str(len(outliers)))
# Out:
# number of outliers:879

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
# your code goes here
def drop_outliers_IQR(df):

   q1=df.quantile(0.25)

   q3=df.quantile(0.75)

   IQR=q3-q1

   not_outliers = df[((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]

   outliers_dropped = outliers.dropna().reset_index()

   return outliers_dropped

df_drop_outlier = drop_outliers_IQR(df['ConvertedComp'])

# %%
df['ConvertedComp'].mean()
# Out:
# 131596.7316197316

# %%
df_drop_outlier.mean()
# Out:
# index              5706.242321
# ConvertedComp    923219.389078
# dtype: float64

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
# your code goes here
df[['Age','CompTotal','ConvertedComp','WorkWeekHrs','CodeRevHrs','Respondent']].corr()
# Out:
#                     Age  CompTotal  ConvertedComp  WorkWeekHrs  CodeRevHrs  \
# Age            1.000000   0.006970       0.105386     0.036518   -0.020469
# CompTotal      0.006970   1.000000       0.001037     0.003510    0.007063
# ConvertedComp  0.105386   0.001037       1.000000     0.021143   -0.033865
# WorkWeekHrs    0.036518   0.003510       0.021143     1.000000    0.026517
# CodeRevHrs    -0.020469   0.007063      -0.033865     0.026517    1.000000
# Respondent     0.004041  -0.013490       0.002181    -0.015314    0.004621
#
#                Respondent
# Age              0.004041
# CompTotal       -0.013490
# ConvertedComp    0.002181
# WorkWeekHrs     -0.015314
# CodeRevHrs       0.004621
# Respondent       1.000000

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
